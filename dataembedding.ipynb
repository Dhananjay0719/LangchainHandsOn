# %%
OPEN_API_KEY="sk------"

# %%
import os 
from dotenv import load_dotenv
load_dotenv()

# %%
os.environ["OPEN_API_KEY"]=os.getenv("OPEN_API_KEY")

# %%
from langchain_openai import OpenAIEmbeddings
embeddings=OpenAIEmbeddings(model="text-embedding-3-large").  #to change dimensions give it in dimensions attribute

# %%
text="THIS IS A DUMMY TEST TO LEARN EMBEDDING TECHNIQUES"
query_result=embeddings.embed_query(text)

# %% [markdown]
# USING EMBEDDINGS AND STORING IN VECTOR DB

# %%
from langchain_community.vectorstores import Chroma

db=Chroma.from_documents(yourdocs,embeddings)

retrived_val=db.similarity_search("text for searching")
